# %% [markdown]
# ## Project: Querying and Filtering Pokemon data
#
# This project will help you practice your pandas querying and filtering skills. Let's begin!
#
# <center>
# <img src="./mikel-DypO_XgAE4Y-unsplash.jpg" >
#     <p align="center">
#         Photo by <a href="https://unsplash.com/@mykelgran?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Mikel</a> on <a href="https://unsplash.com/s/photos/pokemon?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>.
#     </p>
# </center>

# %% [markdown]
# ### Task 0 - Setup
#
# There isn't much to do here, we'll provide the required imports and the read the pokemon CSV we'll be working with.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65  \
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           721 non-null    int64
#  1   Name        721 non-null    object
#  2   Type 1      721 non-null    object
#  3   Type 2      359 non-null    object
#  4   Total       721 non-null    int64
#  5   HP          721 non-null    int64
#  6   Attack      721 non-null    int64
#  7   Defense     721 non-null    int64
#  8   Sp. Atk     721 non-null    int64
#  9   Sp. Def     721 non-null    int64
#  10  Speed       721 non-null    int64
#  11  Generation  721 non-null    int64
#  12  Legendary   721 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 68.4+ KB

# %%
df.describe()
# Out:
#                #       Total          HP      Attack     Defense     Sp. Atk
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000  \
# mean   361.00000  417.945908   68.380028   75.124827   70.697642   68.848821
# std    208.27906  109.663671   25.848272   29.070335   29.194941   28.898590
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   54.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   75.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#           Sp. Def       Speed  Generation
# count  721.000000  721.000000  721.000000
# mean    69.180305   65.714286    3.323162
# std     26.899364   27.277920    1.669873
# min     20.000000    5.000000    1.000000
# 25%     50.000000   45.000000    2.000000
# 50%     65.000000   65.000000    3.000000
# 75%     85.000000   85.000000    5.000000
# max    230.000000  160.000000    6.000000

# %% [markdown]
# #### Distribution of Pokemon Types:

# %%
df['Type 1'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='tab20c', figsize=(10, 8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Distribution of Pokemon Totals:

# %%
df['Total'].plot(kind='hist', figsize=(10, 8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Total'].plot(kind='box', vert=False, figsize=(10, 5))
# Out:
# <Axes: >

# %% [markdown]
# #### Distribution of Legendary Pokemons:

# %%
df['Legendary'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Set3', figsize=(10, 8))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Basic filtering
#
# Let's start with a few simple activities regarding filtering.

# %% [markdown]
# ##### 1. How many Pokemons exist with an `Attack` value greater than 150?

# %% [markdown]
# Doing a little bit of visual exploration, we can have a sense of the most "powerful" pokemons (defined by their "Attack" feature). A boxplot is a great way to visualize this:

# %%
sns.boxplot(data=df, x='Attack')
# Out:
# <Axes: xlabel='Attack'>

# %%
# Try your code here
df.loc[df['Attack'] > 150]
df.query("`Attack` > 150") 
(df['Attack'] > 150).sum()
# Out:
# 3

# %% [markdown]
# ##### 2. Select all pokemons with a Speed of `10` or less

# %%
sns.boxplot(data=df, x='Speed')
# Out:
# <Axes: xlabel='Speed'>

# %%
slow_pokemons_df = df.loc[df['Speed'] <= 10]

# %% [markdown]
# ##### 3. How many Pokemons have a `Sp. Def` value of 25 or less?

# %%
# Try your code here
df.loc[df['Sp. Def'] <= 25]
(df['Sp. Def'] <= 25).sum()
# Out:
# 17

# %% [markdown]
# ##### 4. Select all the Legendary pokemons

# %%
# Try your code here
legendary_df = df['Legendary'].sum()
df[df['Legendary'] == True]
# Out:
#        #                      Name    Type 1    Type 2  Total   HP  Attack
# 143  144                  Articuno       Ice    Flying    580   90      85  \
# 144  145                    Zapdos  Electric    Flying    580   90      90
# 145  146                   Moltres      Fire    Flying    580   90     100
# 149  150                    Mewtwo   Psychic  Fighting    680  106     110
# 242  243                    Raikou  Electric       NaN    580   90      85
# 243  244                     Entei      Fire       NaN    580  115     115
# 244  245                   Suicune     Water       NaN    580  100      75
# 248  249                     Lugia   Psychic    Flying    680  106      90
# 249  250                     Ho-oh      Fire    Flying    680  106     130
# 376  377                  Regirock      Rock       NaN    580   80     100
# 377  378                    Regice       Ice       NaN    580   80      50
# 378  379                 Registeel     Steel       NaN    580   80      75
# 379  380                    Latias    Dragon   Psychic    600   80      80
# 380  381                    Latios    Dragon   Psychic    600   80      90
# 381  382                    Kyogre     Water       NaN    670  100     100
# 382  383                   Groudon    Ground      Fire    670  100     150
# 383  384                  Rayquaza    Dragon    Flying    680  105     150
# 384  385                   Jirachi     Steel   Psychic    600  100     100
# 385  386        DeoxysNormal Forme   Psychic       NaN    600   50     150
# 479  480                      Uxie   Psychic       NaN    580   75      75
# 480  481                   Mesprit   Psychic       NaN    580   80     105
# 481  482                     Azelf   Psychic       NaN    580   75     125
# 482  483                    Dialga     Steel    Dragon    680  100     120
# 483  484                    Palkia     Water    Dragon    680   90     120
# 484  485                   Heatran      Fire     Steel    600   91      90
# 485  486                 Regigigas    Normal       NaN    670  110     160
# 486  487     GiratinaAltered Forme     Ghost    Dragon    680  150     100
# 490  491                   Darkrai      Dark       NaN    600   70      90
# 491  492         ShayminLand Forme     Grass    Flying    600  100     100
# 492  493                    Arceus    Normal       NaN    720  120     120
# 493  494                   Victini   Psychic      Fire    600  100     100
# 637  638                  Cobalion     Steel  Fighting    580   91      90
# 638  639                 Terrakion      Rock  Fighting    580   91     129
# 639  640                  Virizion     Grass  Fighting    580   91      90
# 640  641   TornadusIncarnate Forme    Flying       NaN    580   79     115
# 641  642  ThundurusIncarnate Forme  Electric    Flying    580   79     115
# 642  643                  Reshiram    Dragon      Fire    680  100     120
# 643  644                    Zekrom    Dragon  Electric    680  100     150
# 644  645   LandorusIncarnate Forme    Ground    Flying    600   89     125
# 645  646                    Kyurem    Dragon       Ice    660  125     130
# 715  716                   Xerneas     Fairy       NaN    680  126     131
# 716  717                   Yveltal      Dark    Flying    680  126     131
# 717  718          Zygarde50% Forme    Dragon    Ground    600  108     100
# 718  719                   Diancie      Rock     Fairy    600   50     100
# 719  720       HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 720  721                 Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 143      100       95      125     85           1       True
# 144       85      125       90    100           1       True
# 145       90      125       85     90           1       True
# 149       90      154       90    130           1       True
# 242       75      115      100    115           2       True
# 243       85       90       75    100           2       True
# 244      115       90      115     85           2       True
# 248      130       90      154    110           2       True
# 249       90      110      154     90           2       True
# 376      200       50      100     50           3       True
# 377      100      100      200     50           3       True
# 378      150       75      150     50           3       True
# 379       90      110      130    110           3       True
# 380       80      130      110    110           3       True
# 381       90      150      140     90           3       True
# 382      140      100       90     90           3       True
# 383       90      150       90     95           3       True
# 384      100      100      100    100           3       True
# 385       50      150       50    150           3       True
# 479      130       75      130     95           4       True
# 480      105      105      105     80           4       True
# 481       70      125       70    115           4       True
# 482      120      150      100     90           4       True
# 483      100      150      120    100           4       True
# 484      106      130      106     77           4       True
# 485      110       80      110    100           4       True
# 486      120      100      120     90           4       True
# 490       90      135       90    125           4       True
# 491      100      100      100    100           4       True
# 492      120      120      120    120           4       True
# 493      100      100      100    100           5       True
# 637      129       90       72    108           5       True
# 638       90       72       90    108           5       True
# 639       72       90      129    108           5       True
# 640       70      125       80    111           5       True
# 641       70      125       80    111           5       True
# 642      100      150      120     90           5       True
# 643      120      120      100     90           5       True
# 644       90      115       80    101           5       True
# 645       90      130       90     95           5       True
# 715       95      131       98     99           6       True
# 716       95      131       98     99           6       True
# 717      121       81       95     95           6       True
# 718      150      100      150     50           6       True
# 719       60      150      130     70           6       True
# 720      120      130       90     70           6       True

# %% [markdown]
# ##### 5. Find the outlier

# %% [markdown]
# Find the pokemon that is clearly an outlier in terms of Attack / Defense:

# %%
ax = sns.scatterplot(data=df, x="Defense", y="Attack")
ax.annotate(
    "Who's this guy?", xy=(228, 10), xytext=(150, 10), color='red',
    arrowprops=dict(arrowstyle="->", color='red')
)
# Out:
# Text(150, 10, "Who's this guy?")

# %%
# Try your code here
df.sort_values(by=['Defense','Attack'], ascending=[False, True])
# Out:
#        #      Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk
# 112  113   Chansey    Normal      NaN    450  250       5        5       35  \
# 439  440   Happiny    Normal      NaN    220  100       5        5       15
# 241  242   Blissey    Normal      NaN    540  255      10       10       75
# 237  238  Smoochum       Ice  Psychic    305   45      30       15       85
# 171  172     Pichu  Electric      NaN    205   20      40       15       35
# ..   ...       ...       ...      ...    ...  ...     ...      ...      ...
# 305  306    Aggron     Steel     Rock    530   70     110      180       60
# 712  713   Avalugg       Ice      NaN    514   95     117      184       44
# 376  377  Regirock      Rock      NaN    580   80     100      200       50
# 207  208   Steelix     Steel   Ground    510   75      85      200       55
# 212  213   Shuckle       Bug     Rock    505   20      10      230       10
#
#      Sp. Def  Speed  Generation  Legendary
# 112      105     50           1      False
# 439       65     30           4      False
# 241      135     55           2      False
# 237       65     65           2      False
# 171       35     60           2      False
# ..       ...    ...         ...        ...
# 305       60     50           3      False
# 712       46     28           6      False
# 376      100     50           3       True
# 207       65     30           2      False
# 212      230      5           2      False
#
# [721 rows x 13 columns]

# %% [markdown]
# ### Advanced selection
#
# Now let's use boolean operators to create more advanced expressions

# %% [markdown]
# ##### 6. How many Fire-Flying Pokemons are there?

# %%
# Try your code here
(
    (df['Type 1'] == 'Fire') &
    (df['Type 2'] == 'Flying')
).sum()

df.loc[
    (df['Type 1'] == 'Fire') &
    (df['Type 2'] == 'Flying')
]
df.query("`Type 1` == 'Fire' and `Type 2` == 'Flying'")
# Out:
#        #         Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk
# 5      6    Charizard   Fire  Flying    534   78      84       78      109  \
# 145  146      Moltres   Fire  Flying    580   90     100       90      125
# 249  250        Ho-oh   Fire  Flying    680  106     130       90      110
# 661  662  Fletchinder   Fire  Flying    382   62      73       55       56
# 662  663   Talonflame   Fire  Flying    499   78      81       71       74
#
#      Sp. Def  Speed  Generation  Legendary
# 5         85    100           1      False
# 145       85     90           1       True
# 249      154     90           2       True
# 661       52     84           6      False
# 662       69    126           6      False

# %% [markdown]
# ##### 7. How many 'Poison' pokemons are across both types?

# %%
# Try your code here
df.query("`Type 1` == 'Poison' or `Type 2` == 'Poison'").shape
((df['Type 1'] =='Poison')|(df['Type 2'] =='Poison')).sum()
# Out:
# 59

# %% [markdown]
# ##### 8. Name the pokemon of `Type 1` *Ice* which has the strongest defense?

# %%
# Try your code here
df.loc[df['Type 1'] == 'Ice', 'Defense'].max()
df.loc[
    (df['Type 1'] == 'Ice')&
    (df['Defense'] == df.loc[df['Type 1'] == 'Ice', 'Defense'].max())
]
df.loc[df['Type 1'] == 'Ice'].sort_values("Defense", ascending=False).head()
# Out:
#        #      Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk
# 712  713   Avalugg    Ice     NaN    514   95     117      184       44  \
# 470  471   Glaceon    Ice     NaN    525   65      60      110      130
# 143  144  Articuno    Ice  Flying    580   90      85      100       95
# 377  378    Regice    Ice     NaN    580   80      50      100      100
# 364  365   Walrein    Ice   Water    530  110      80       90       95
#
#      Sp. Def  Speed  Generation  Legendary
# 712       46     28           6      False
# 470       95     65           4      False
# 143      125     85           1       True
# 377      200     50           3       True
# 364       90     65           3      False

# %% [markdown]
# ##### 9. What's the most common type of Legendary Pokemons?

# %%
# Try your code here
df.loc[df['Legendary'], 'Type 1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type 1'>

# %% [markdown]
# ##### 10. What's the most powerful pokemon from the first 3 generations, of type water?

# %%
# Try your code here
df['Generation'].value_counts(sort=False)
df['Generation'].isin([1,2,3]).sum()
(
    (df['Generation'] == 1) |
    (df['Generation'] == 2) |
    (df['Generation'] == 3) 
).sum()

df.loc[
    (df['Type 1'] == 'Water') &
    df['Generation'].isin([1,2,3])
].sort_values(by='Total',ascending=False).head()
# Out:
#        #      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk
# 348  349    Feebas  Water     NaN    200  20      15       20       10  \
# 128  129  Magikarp  Water     NaN    200  20      10       55       15
# 193  194    Wooper  Water  Ground    210  55      45       45       25
# 269  270     Lotad  Water   Grass    220  40      30       30       40
# 182  183    Marill  Water   Fairy    250  70      20       50       20
#
#      Sp. Def  Speed  Generation  Legendary
# 348       55     80           3      False
# 128       20     80           1      False
# 193       25     15           2      False
# 269       50     30           3      False
# 182       50     40           2      False

# %% [markdown]
# ##### 11. What's the most powerful Dragon from the last two generations?

# %%
# Try your code here
df.loc[
    ((df['Type 1'] == 'Dragon')|(df['Type 2'] == 'Dragon')) &
    (df['Generation'].isin({5,6}))
].sort_values(by='Total', ascending=False)
df.query(
    "(`Type 1` == 'Dragon' or `Type 2` == 'Dragon') and Generation in [5,6]"
).sort_values(by='Total', ascending=False)
# Out:
#        #              Name  Type 1    Type 2  Total   HP  Attack  Defense
# 643  644            Zekrom  Dragon  Electric    680  100     150      120  \
# 642  643          Reshiram  Dragon      Fire    680  100     120      100
# 645  646            Kyurem  Dragon       Ice    660  125     130       90
# 634  635         Hydreigon    Dark    Dragon    600   92     105       90
# 705  706            Goodra  Dragon       NaN    600   90     100       70
# 717  718  Zygarde50% Forme  Dragon    Ground    600  108     100      121
# 611  612           Haxorus  Dragon       NaN    540   76     147       90
# 714  715           Noivern  Flying    Dragon    535   85      70       80
# 696  697         Tyrantrum    Rock    Dragon    521   82     121      119
# 690  691          Dragalge  Poison    Dragon    494   65      75       90
# 620  621         Druddigon  Dragon       NaN    485   77     120       90
# 704  705           Sliggoo  Dragon       NaN    452   68      75       53
# 633  634          Zweilous    Dark    Dragon    420   72      85       70
# 610  611           Fraxure  Dragon       NaN    410   66     117       70
# 695  696            Tyrunt    Rock    Dragon    362   58      89       77
# 609  610              Axew  Dragon       NaN    320   46      87       60
# 632  633             Deino    Dark    Dragon    300   52      65       50
# 703  704             Goomy  Dragon       NaN    300   45      50       35
# 713  714            Noibat  Flying    Dragon    245   40      30       35
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 643      120      100     90           5       True
# 642      150      120     90           5       True
# 645      130       90     95           5       True
# 634      125       90     98           5      False
# 705      110      150     80           6      False
# 717       81       95     95           6       True
# 611       60       70     97           5      False
# 714       97       80    123           6      False
# 696       69       59     71           6      False
# 690       97      123     44           6      False
# 620       60       90     48           5      False
# 704       83      113     60           6      False
# 633       65       70     58           5      False
# 610       40       50     67           5      False
# 695       45       45     48           6      False
# 609       30       40     57           5      False
# 632       45       50     38           5      False
# 703       55       75     40           6      False
# 713       45       40     55           6      False

# %% [markdown]
# ##### 12. Select most powerful Fire-type pokemons

# %%
# Try your code here
powerful_fire_df = df.query("`Attack` > 100 and `Type 1` == 'Fire'")

# %% [markdown]
# ##### 13. Select all Water-type, Flying-type pokemons

# %%
# Try your code here
water_flying_df = df.query("`Type 1` == 'water' and `Type 2` == 'Flying'")

# %% [markdown]
# ##### 14. Select specific columns of Legendary pokemons of type Fire

# %%
# Try your code here
legendary_fire_df = df.loc[
    (
        (df['Type 1'] == 'Fire') &
        df['Legendary']
    ), 
    ['Name', 'Attack', 'Generation']
]

# %% [markdown]
# ##### 15. Select Slow and Fast pokemons

# %% [markdown]
# This is the distribution of speed of the pokemons. The red lines indicate those bottom 5% and top 5% pokemons by speed:

# %%
ax = df['Speed'].plot(kind='hist', figsize=(10, 5), bins=100)
ax.axvline(df['Speed'].quantile(.05), color='red')
ax.axvline(df['Speed'].quantile(.95), color='red')

# %%
# Try your code here
bot_5 = df['Speed'].quantile(0.05)
top_5 = df['Speed'].quantile(0.95)
(bot_5, top_5)

slow_fast_df = df.query("`Speed` < @bot_5 or `Speed` > @top_5")
df.loc[
    (df['Speed'] < bot_5) |
    (df['Speed'] > top_5)
]
# Out:
#        #        Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk
# 38    39  Jigglypuff    Normal   Fairy    270  115      45       20       45  \
# 50    51     Dugtrio    Ground     NaN    405   35      80       50       50
# 52    53     Persian    Normal     NaN    440   65      70       60       65
# 64    65    Alakazam   Psychic     NaN    500   55      50       45      135
# 73    74     Geodude      Rock  Ground    300   40      80      100       30
# ..   ...         ...       ...     ...    ...  ...     ...      ...      ...
# 657  658    Greninja     Water    Dark    530   72      95       67      103
# 662  663  Talonflame      Fire  Flying    499   78      81       71       74
# 681  682    Spritzee     Fairy     NaN    341   78      52       60       63
# 700  701    Hawlucha  Fighting  Flying    500   78      92       75       74
# 714  715     Noivern    Flying  Dragon    535   85      70       80       97
#
#      Sp. Def  Speed  Generation  Legendary
# 38        25     20           1      False
# 50        70    120           1      False
# 52        65    115           1      False
# 64        95    120           1      False
# 73        30     20           1      False
# ..       ...    ...         ...        ...
# 657       71    122           6      False
# 662       69    126           6      False
# 681       65     23           6      False
# 700       63    118           6      False
# 714       80    123           6      False
#
# [68 rows x 13 columns]

# %% [markdown]
# ##### 16. Find the Ultra Powerful Legendary Pokemon

# %%
fig, ax = plt.subplots(figsize=(14, 7))
sns.scatterplot(data=df, x="Defense", y="Attack", hue='Legendary', ax=ax)
ax.annotate(
    "Who's this guy?", xy=(140, 150), xytext=(160, 150), color='red',
    arrowprops=dict(arrowstyle="->", color='red')
)
# Out:
# Text(160, 150, "Who's this guy?")

# %%
# Try your code here
df.loc[df['Legendary']].sort_values(by=['Attack','Defense'], ascending=False)
# Out:
#        #                      Name    Type 1    Type 2  Total   HP  Attack
# 485  486                 Regigigas    Normal       NaN    670  110     160  \
# 382  383                   Groudon    Ground      Fire    670  100     150
# 643  644                    Zekrom    Dragon  Electric    680  100     150
# 383  384                  Rayquaza    Dragon    Flying    680  105     150
# 385  386        DeoxysNormal Forme   Psychic       NaN    600   50     150
# 715  716                   Xerneas     Fairy       NaN    680  126     131
# 716  717                   Yveltal      Dark    Flying    680  126     131
# 249  250                     Ho-oh      Fire    Flying    680  106     130
# 645  646                    Kyurem    Dragon       Ice    660  125     130
# 638  639                 Terrakion      Rock  Fighting    580   91     129
# 644  645   LandorusIncarnate Forme    Ground    Flying    600   89     125
# 481  482                     Azelf   Psychic       NaN    580   75     125
# 482  483                    Dialga     Steel    Dragon    680  100     120
# 492  493                    Arceus    Normal       NaN    720  120     120
# 483  484                    Palkia     Water    Dragon    680   90     120
# 642  643                  Reshiram    Dragon      Fire    680  100     120
# 243  244                     Entei      Fire       NaN    580  115     115
# 640  641   TornadusIncarnate Forme    Flying       NaN    580   79     115
# 641  642  ThundurusIncarnate Forme  Electric    Flying    580   79     115
# 720  721                 Volcanion      Fire     Water    600   80     110
# 149  150                    Mewtwo   Psychic  Fighting    680  106     110
# 719  720       HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 480  481                   Mesprit   Psychic       NaN    580   80     105
# 376  377                  Regirock      Rock       NaN    580   80     100
# 718  719                   Diancie      Rock     Fairy    600   50     100
# 717  718          Zygarde50% Forme    Dragon    Ground    600  108     100
# 486  487     GiratinaAltered Forme     Ghost    Dragon    680  150     100
# 384  385                   Jirachi     Steel   Psychic    600  100     100
# 491  492         ShayminLand Forme     Grass    Flying    600  100     100
# 493  494                   Victini   Psychic      Fire    600  100     100
# 145  146                   Moltres      Fire    Flying    580   90     100
# 381  382                    Kyogre     Water       NaN    670  100     100
# 248  249                     Lugia   Psychic    Flying    680  106      90
# 637  638                  Cobalion     Steel  Fighting    580   91      90
# 484  485                   Heatran      Fire     Steel    600   91      90
# 490  491                   Darkrai      Dark       NaN    600   70      90
# 144  145                    Zapdos  Electric    Flying    580   90      90
# 380  381                    Latios    Dragon   Psychic    600   80      90
# 639  640                  Virizion     Grass  Fighting    580   91      90
# 143  144                  Articuno       Ice    Flying    580   90      85
# 242  243                    Raikou  Electric       NaN    580   90      85
# 379  380                    Latias    Dragon   Psychic    600   80      80
# 378  379                 Registeel     Steel       NaN    580   80      75
# 479  480                      Uxie   Psychic       NaN    580   75      75
# 244  245                   Suicune     Water       NaN    580  100      75
# 377  378                    Regice       Ice       NaN    580   80      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 485      110       80      110    100           4       True
# 382      140      100       90     90           3       True
# 643      120      120      100     90           5       True
# 383       90      150       90     95           3       True
# 385       50      150       50    150           3       True
# 715       95      131       98     99           6       True
# 716       95      131       98     99           6       True
# 249       90      110      154     90           2       True
# 645       90      130       90     95           5       True
# 638       90       72       90    108           5       True
# 644       90      115       80    101           5       True
# 481       70      125       70    115           4       True
# 482      120      150      100     90           4       True
# 492      120      120      120    120           4       True
# 483      100      150      120    100           4       True
# 642      100      150      120     90           5       True
# 243       85       90       75    100           2       True
# 640       70      125       80    111           5       True
# 641       70      125       80    111           5       True
# 720      120      130       90     70           6       True
# 149       90      154       90    130           1       True
# 719       60      150      130     70           6       True
# 480      105      105      105     80           4       True
# 376      200       50      100     50           3       True
# 718      150      100      150     50           6       True
# 717      121       81       95     95           6       True
# 486      120      100      120     90           4       True
# 384      100      100      100    100           3       True
# 491      100      100      100    100           4       True
# 493      100      100      100    100           5       True
# 145       90      125       85     90           1       True
# 381       90      150      140     90           3       True
# 248      130       90      154    110           2       True
# 637      129       90       72    108           5       True
# 484      106      130      106     77           4       True
# 490       90      135       90    125           4       True
# 144       85      125       90    100           1       True
# 380       80      130      110    110           3       True
# 639       72       90      129    108           5       True
# 143      100       95      125     85           1       True
# 242       75      115      100    115           2       True
# 379       90      110      130    110           3       True
# 378      150       75      150     50           3       True
# 479      130       75      130     95           4       True
# 244      115       90      115     85           2       True
# 377      100      100      200     50           3       True

# %% [markdown]
# ### The End!
